# %% [markdown]
# # 🚀 FULL LOAD – Carga Completa del CSV (Nivel-1 · Fase-0)

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# --------------------------------
# CONFIG
# --------------------------------
CSV_FILE = "../yellow_tripdata_2024-01.csv"
TABLE_NAME = "yellow_taxi_data"

# %%
# --------------------------------
# 1) Lectura completa del CSV
# --------------------------------
df = pd.read_csv(CSV_FILE)

# %%
# --------------------------------
# 2) Conexión a Postgres
# --------------------------------
engine = create_engine(
    "postgresql://root:root@localhost:5432/ny_taxi"
)

# %%
# --------------------------------
# 3) Creación de tabla (solo esquema)
# --------------------------------
df.head(n=0).to_sql(
    name=TABLE_NAME,
    con=engine,
    if_exists="replace"
)

# %%
# --------------------------------
# 4) Carga completa de datos
# --------------------------------
# %time df.to_sql(name=TABLE_NAME,con=engine, if_exists="append")

# %%
# CPU times: user 9min 37s, sys: 2min 21s, total: 11min 58s
# Wall time: 15min 3s
